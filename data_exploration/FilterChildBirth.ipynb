# %% [markdown]
# ## Split the cleaned dataset into two data frames according to the value of column "Birth Weight":
# * SPARCS-2017-birth.csv: records that has "Birth Weight". Same strcuture as the cleaned csv (224082 rows \* 25 cols). According to "CCS Diagnosis Description", not only contains Liveborn, but also contains liveborn-related disease.
# * SPARCS-2017-Notbirth.csv: records that has Null "Birth Weight". Similar strcuture to the cleaned csv but dropped the column "Birth Weight" (2080234 rows \* 24 col).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 

filename = '/Users/mac/Desktop/BigData_ProjectData/SPARCS-2017.csv'

# %%
data = pd.read_csv(filename)
print(np.shape(data))
data.head()
# Out:
# /Users/mac/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (2343569, 34)
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         Hudson Valley     Westchester                     5903001.0
# 1         Hudson Valley     Westchester                     5903001.0
# 2         Hudson Valley     Westchester                     5903001.0
# 3         Hudson Valley     Westchester                     5903001.0
# 4         Hudson Valley     Westchester                     5903001.0
#
#    Permanent Facility Id                     Facility Name Age Group  \
# 0                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# 1                 1061.0  Montefiore Mount Vernon Hospital  50 to 69
# 2                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# ...

# %%
data2 = data.dropna(subset = ['Hospital Service Area','Zip Code - 3 digits',
                             'APR Risk of Mortality'])

# %%
droplist = ["Discharge Year","Abortion Edit Indicator",
            "Operating Certificate Number","Permanent Facility Id",
            "CCS Diagnosis Code","CCS Procedure Code",
            "APR MDC Code","APR Severity of Illness Code",
           "APR DRG Code"]
data3 = data2.drop(droplist, axis=1)
print(np.shape(data3))
data3.head()
# Out:
# (2304316, 25)
#   Hospital Service Area Hospital County                     Facility Name  \
# 1         Hudson Valley     Westchester  Montefiore Mount Vernon Hospital
# 2         Hudson Valley     Westchester  Montefiore Mount Vernon Hospital
# 3         Hudson Valley     Westchester  Montefiore Mount Vernon Hospital
# 4         Hudson Valley     Westchester  Montefiore Mount Vernon Hospital
# 5         Hudson Valley     Westchester  Montefiore Mount Vernon Hospital
#
#   Age Group Zip Code - 3 digits Gender                    Race  \
# 1  50 to 69                 105      M                   White
# 2  30 to 49                 105      F                   White
# 3  50 to 69                 105      F                   White
# 4  18 to 29                 105      F                   White
# 5  50 to 69                 105      M  Black/African American
#
#            Ethnicity Length of Stay Type of Admission  ...  \
# 1   Spanish/Hispanic              8         Emergency  ...
# ...

# %%
data3[data3["Birth Weight"].notnull()&data3['CCS Diagnosis Description']!='Liveborn']#.loc[:, 'Patient Disposition':'Birth Weight']
# Out:
#         Hospital Service Area Hospital County  \
# 1               Hudson Valley     Westchester
# 2               Hudson Valley     Westchester
# 3               Hudson Valley     Westchester
# 4               Hudson Valley     Westchester
# 5               Hudson Valley     Westchester
# ...                       ...             ...
# 2343563         New York City       Manhattan
# 2343564         Hudson Valley        Rockland
# 2343565         Hudson Valley        Rockland
# 2343567         New York City           Bronx
# 2343568          Finger Lakes         Steuben
#
#                                              Facility Name    Age Group  \
# 1                         Montefiore Mount Vernon Hospital     50 to 69
# 2                         Montefiore Mount Vernon Hospital     30 to 49
# 3                         Montefiore Mount Vernon Hospital     50 to 69
# 4                         Montefiore Mount Vernon Hospital     18 to 29
# ...

# %%
birth = data3[data3["Birth Weight"].notnull()]
not_birth = data3[data3["Birth Weight"].isna()]
print(np.shape(birth),np.shape(not_birth))
# Out:
# (224082, 25) (2080234, 25)

# %%
set(birth["CCS Diagnosis Description"])
# Out:
# {'Abdominal hernia',
#  'Acute and unspecified renal failure',
#  'Acute bronchitis',
#  'Acute cerebrovascular disease',
#  'Administrative/social admission',
#  'Allergic reactions',
#  'Anal and rectal conditions',
#  'Anxiety disorders',
#  'Bacterial infection; unspecified site',
#  'Birth trauma',
#  'Burns',
#  'Cancer; other and unspecified primary',
#  'Cardiac and circulatory congenital anomalies',
#  'Cardiac arrest and ventricular fibrillation',
#  'Cardiac dysrhythmias',
#  'Coagulation and hemorrhagic disorders',
#  'Complication of device; implant or graft',
#  'Complications of surgical procedures or medical care',
#  'Conduction disorders',
#  'Deficiency and other anemia',
#  'Digestive congenital anomalies',
#  'Diseases of mouth; excluding dental',
#  'Diseases of white blood cells',
#  'Encephalitis (except that caused by tuberculosis or sexually transmitted disease)',
#  'Epilepsy; convulsions',
#  'Esophageal disorders',
#  'Essential hypertension',
# ...

# %%
"Livebirth" in set(not_birth["CCS Diagnosis Description"])
# Out:
# False

# %%
birthname = '/Users/mac/Desktop/BigData_ProjectData/SPARCS-2017-birth.csv'
birth.to_csv(birthname, sep='\t', index=False)

# %%
not_birth = not_birth.drop(["Birth Weight"], axis=1)
print(np.shape(not_birth))
not_birth.count()
# Out:
# (2080234, 24)
# Hospital Service Area                  2080234
# Hospital County                        2080234
# Facility Name                          2080234
# Age Group                              2080234
# Zip Code - 3 digits                    2080234
# Gender                                 2080234
# Race                                   2080234
# Ethnicity                              2080234
# Length of Stay                         2080234
# Type of Admission                      2080234
# Patient Disposition                    2080234
# CCS Diagnosis Description              2080234
# CCS Procedure Description              2080234
# APR DRG Description                    2080234
# APR MDC Description                    2080234
# APR Severity of Illness Description    2080234
# APR Risk of Mortality                  2080234
# APR Medical Surgical Description       2080234
# Payment Typology 1                     2080234
# Payment Typology 2                     1329026
# ...

# %%
notname = '/Users/mac/Desktop/BigData_ProjectData/SPARCS-2017-Nobirth.csv'
not_birth.to_csv(notname, sep='\t', index=False)

# %%
test = pd.read_csv(notname,sep='\t')
print(np.shape(test))
test.head()
# Out:
# (2080234, 25)
#    Unnamed: 0 Hospital Service Area Hospital County  \
# 0           1         Hudson Valley     Westchester
# 1           2         Hudson Valley     Westchester
# 2           3         Hudson Valley     Westchester
# 3           4         Hudson Valley     Westchester
# 4           5         Hudson Valley     Westchester
#
#                       Facility Name Age Group Zip Code - 3 digits Gender  \
# 0  Montefiore Mount Vernon Hospital  50 to 69                 105      M
# 1  Montefiore Mount Vernon Hospital  30 to 49                 105      F
# 2  Montefiore Mount Vernon Hospital  50 to 69                 105      F
# 3  Montefiore Mount Vernon Hospital  18 to 29                 105      F
# 4  Montefiore Mount Vernon Hospital  50 to 69                 105      M
#
#                      Race          Ethnicity Length of Stay  ...  \
# 0                   White   Spanish/Hispanic              8  ...
# ...
